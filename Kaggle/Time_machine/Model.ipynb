# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# t

# %%
titanic_data = pd.read_csv('train.csv')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Variable Notes
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

for train_indices, test_indices in split.split(
    titanic_data,
    titanic_data[['Survived', 'Pclass', 'Sex']]
):
    strat_train_set = titanic_data.loc[train_indices]
    strat_test_set = titanic_data.loc[test_indices]

# %%
strat_test_set
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 357          358         0       2          Funk, Miss. Annie Clemmer  female
# 797          798         1       3                   Osman, Mrs. Mara  female
# 372          373         0       3         Beavan, Mr. William Thomas    male
# 852          853         0       3            Boulos, Miss. Nourelain  female
# 690          691         1       1            Dick, Mr. Albert Adrian    male
# ..           ...       ...     ...                                ...     ...
# 624          625         0       3        Bowen, Mr. David John "Dai"    male
# 202          203         0       3         Johanson, Mr. Jakob Alfred    male
# 711          712         0       1                 Klaber, Mr. Herman    male
# 773          774         0       3                    Elias, Mr. Dibo    male
# 542          543         0       3  Andersson, Miss. Sigrid Elisabeth  female
#
# ...

# %%
plt.subplot(1,2,1)
strat_train_set['Survived'].hist()
strat_train_set['Pclass'].hist()

plt.subplot(1,2,2)
strat_test_set['Survived'].hist()
strat_test_set['Pclass'].hist()

plt.show()

# %% [markdown]
# #### We are now using fit transform
#
#     ##### Simple Analogy
#
# Imagine a teacher grading tests.
#
# fit()
#
# The teacher first looks at all scores and learns:
#
# highest mark
# lowest mark
# average
#
# This is “learning from the data.”
#
# transform()
#
# Then the teacher converts scores into percentages using what was learned.
#
# This is “changing the data.”
# ![image.png](attachment:image.png)
#
# OUTPUT
# [[0. ]
#  [0.5]
#  [1. ]]

# %%
from sklearn.base import BaseEstimator,TransformerMixin
from sklearn.impute import SimpleImputer
class AgeImputer(BaseEstimator,TransformerMixin):
    def fit(self,X,y=None):
        return self
    def transform(self, X):
        imputer = SimpleImputer(strategy='mean')
        X['Age'] = imputer.fit_transform(X[['Age']])
        return X

# %% [markdown]
# 👆This code creates a custom transformer for Scikit-learn that fills missing values in the "Age" column using the average age.

# %%
from sklearn.preprocessing import OneHotEncoder
class FeatureEncoder(BaseEstimator,TransformerMixin):
    def fit(self,X,y=None):
        return self
    def transform(self,X):
        encoder  = OneHotEncoder()
        matrix = encoder.fit_transform(X[['Embarked']]).toarray()
        
        column_names = ['C','S','Q','N']
        for i in range(len(matrix.T)):
            X[column_names[i]] = matrix.T[i]
        matrix  = encoder.fit_transform(X[['Sex']]).toarray()

        for i in range(len(matrix.T)):
            X[column_names[i]] = matrix.T[i]
        return X

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class FeatureDropper(BaseEstimator, TransformerMixin):

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X.drop(
            ['Embarked', 'Name', 'Ticket', 'Cabin', 'Sex'],
            axis=1,
            errors='ignore'
        )

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('ageimputer', AgeImputer()),
    ('featureencoder', FeatureEncoder()),
    ('featuredropper', FeatureDropper())
])

# %%
strat_train_set = pipeline.fit_transform(strat_train_set)

# %%
strat_train_set
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare    C  \
# 200          201         0       3  28.000000      0      0    9.5000  0.0
# 498          499         0       1  25.000000      1      2  151.5500  1.0
# 130          131         0       3  33.000000      0      0    7.8958  0.0
# 820          821         1       1  52.000000      1      1   93.5000  1.0
# 452          453         0       1  30.000000      0      0   27.7500  0.0
# ..           ...       ...     ...        ...    ...    ...       ...  ...
# 768          769         0       3  30.124206      1      0   24.1500  0.0
# 867          868         0       1  31.000000      0      0   50.4958  0.0
# 74            75         1       3  32.000000      0      0   56.4958  0.0
# 108          109         0       3  38.000000      0      0    7.8958  0.0
# 837          838         0       3  30.124206      0      0    8.0500  0.0
#
#        S    Q    N
# 200  1.0  1.0  0.0
# 498  0.0  1.0  0.0
# ...

# %%
strat_train_set.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 712 entries, 200 to 837
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Age          712 non-null    float64
#  4   SibSp        712 non-null    int64
#  5   Parch        712 non-null    int64
#  6   Fare         712 non-null    float64
#  7   C            712 non-null    float64
#  8   S            712 non-null    float64
#  9   Q            712 non-null    float64
#  10  N            712 non-null    float64
# dtypes: float64(6), int64(5)
# memory usage: 66.8 KB

# %%
X
# Out:
#      PassengerId  Pclass                               Name     Sex   Age  \
# 357          358       2          Funk, Miss. Annie Clemmer  female  38.0
# 797          798       3                   Osman, Mrs. Mara  female  31.0
# 372          373       3         Beavan, Mr. William Thomas    male  19.0
# 852          853       3            Boulos, Miss. Nourelain  female   9.0
# 690          691       1            Dick, Mr. Albert Adrian    male  31.0
# ..           ...     ...                                ...     ...   ...
# 624          625       3        Bowen, Mr. David John "Dai"    male  21.0
# 202          203       3         Johanson, Mr. Jakob Alfred    male  34.0
# 711          712       1                 Klaber, Mr. Herman    male   NaN
# 773          774       3                    Elias, Mr. Dibo    male   NaN
# 542          543       3  Andersson, Miss. Sigrid Elisabeth  female  11.0
#
#      SibSp  Parch   Ticket     Fare Cabin Embarked
# ...

# %%
from sklearn.preprocessing import StandardScaler

X = strat_test_set.drop(["Survived","Name","Sex","Embarked","Cabin","Ticket"], axis=1)
Y = strat_test_set["Survived"]
X
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare
# 357          358       2  38.0      0      0  13.0000
# 797          798       3  31.0      0      0   8.6833
# 372          373       3  19.0      0      0   8.0500
# 852          853       3   9.0      1      1  15.2458
# 690          691       1  31.0      1      0  57.0000
# ..           ...     ...   ...    ...    ...      ...
# 624          625       3  21.0      0      0  16.1000
# 202          203       3  34.0      0      0   6.4958
# 711          712       1   NaN      0      0  26.5500
# 773          774       3   NaN      0      0   7.2250
# 542          543       3  11.0      4      2  31.2750
#
# [179 rows x 6 columns]

# %%
scaler = StandardScaler()
x_data = scaler.fit_transform(X)
y_data = Y.to_numpy()

# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
clf = RandomForestClassifier()
param_gird = [
{"n_estimators": [10, 100, 200, 500], "max_depth": [None, 5, 10], "min_samples_split": [2,3,4]}]

# %%
grid_search = GridSearchCV(clf,param_gird,cv = 3,scoring="accuracy",return_train_score=True)
grid_search.fit(x_data,y_data)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid=[{'max_depth': [None, 5, 10],
#                           'min_samples_split': [2, 3, 4],
#                           'n_estimators': [10, 100, 200, 500]}],
#              return_train_score=True, scoring='accuracy')

# %%
final_clf = grid_search.best_estimator_
final_clf
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=500)

# %%
strat_test_set
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare    C  \
# 357          358         0       2  38.000000      0      0  13.0000  1.0
# 797          798         1       3  31.000000      0      0   8.6833  1.0
# 372          373         0       3  19.000000      0      0   8.0500  0.0
# 852          853         0       3   9.000000      1      1  15.2458  1.0
# 690          691         1       1  31.000000      1      0  57.0000  0.0
# ..           ...       ...     ...        ...    ...    ...      ...  ...
# 624          625         0       3  21.000000      0      0  16.1000  0.0
# 202          203         0       3  34.000000      0      0   6.4958  0.0
# 711          712         0       1  27.971631      0      0  26.5500  0.0
# 773          774         0       3  27.971631      0      0   7.2250  0.0
# 542          543         0       3  11.000000      4      2  31.2750  1.0
#
#        S    Q    N
# 357  0.0  1.0  0.0
# 797  0.0  1.0  0.0
# ...

# %%
strat_test_set = pipeline.fit_transform(strat_test_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 strat_test_set = pipeline.fit_transform(strat_test_set)
#
# File c:\PES\GCI\Python\.venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\PES\GCI\Python\.venv\Lib\site-packages\sklearn\pipeline.py:677, in Pipeline.fit_transform(self, X, y, **params)
#     638 """Fit the model and transform with the final estimator.
#     639
#     640 Fit all the transformers one after the other and sequentially transform
# ...
